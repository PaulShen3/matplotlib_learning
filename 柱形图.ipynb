# %% [markdown]
# # Matplotlib柱形图

# %% [markdown]
# plt.bar(x,height,width=0.8,bottom=None,*,aligh='center',data=None,**kwargs)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
plt.bar(x,y,color='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
colors = ['#4CAF50','red','hotpink','blue']
plt.bar(x,y,color = colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
colors = ['#4CAF50','red','hotpink','blue']
plt.bar(x,y,color = colors,width=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Runoob-1','Runoob-2','Runoob-3','C-RUNOOB'])
y = np.array([12,22,6,18])
colors = ['#4CAF50','red','hotpink','blue']
plt.barh(x,y,color = colors,height=0.2)
plt.show()
